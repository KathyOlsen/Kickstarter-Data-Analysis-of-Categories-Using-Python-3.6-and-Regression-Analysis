# %%
import pandas as pd

Location = "KickstarterComboPruned.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#       ID                                               name main_category  \
# 0   5971              An American Apocalypse: The Reckoning        Comics
# 1  18520                                 Grandma's are Life         Music
# 2  21109                                               Meta           Art
# 3  21371                                  Water Powered Car    Technology
# 4  24380  Puss N' Books: A relaxing cat cafe and bookstore.          Food
#
#           category country       state     goal  pledged currency  \
# 0           Comics      US      failed  48000.0    376.0      USD
# 1      World Music      US      failed  15000.0     62.0      USD
# 2  Performance Art      GB  successful    150.0    173.0      GBP
# 3       Technology      US      failed  75000.0    120.0      USD
# 4           Spaces      US      failed  20000.0    776.0      USD
#
#               launched             deadline  backers     state_recat  \
# ...

# %%
df.dtypes
# Out:
# ID                  int64
# name               object
# main_category      object
# category           object
# country            object
# state              object
# goal              float64
# pledged           float64
# currency           object
# launched           object
# deadline           object
# backers             int64
# state_recat        object
# not_successful      int64
# successful          int64
# usd_pledged       float64
# USD                 int64
# not_USD             int64
# ratio             float64
# usd_goal          float64
# dtype: object

# %%
df.count()
# Out:
# ID                366786
# name              366785
# main_category     366786
# category          366786
# country           366786
# state             366786
# goal              366786
# pledged           366786
# currency          366786
# launched          366786
# deadline          366786
# backers           366786
# state_recat       366786
# not_successful    366786
# successful        366786
# usd_pledged       366786
# USD               366786
# not_USD           366786
# ratio             366786
# usd_goal          366786
# dtype: int64

# %%
df.describe()
# Out:
#                  ID          goal       pledged        backers  \
# count  3.667860e+05  3.667860e+05  3.667860e+05  366786.000000
# mean   1.072195e+09  4.648947e+04  9.811197e+03     107.836362
# std    6.193353e+08  1.110611e+06  9.670281e+04     918.367627
# min    5.971000e+03  1.000000e-02  0.000000e+00       0.000000
# 25%    5.349251e+08  2.000000e+03  3.500000e+01       2.000000
# 50%    1.071315e+09  5.250000e+03  6.400000e+02      13.000000
# 75%    1.607617e+09  1.600000e+04  4.135000e+03      58.000000
# max    2.147476e+09  1.000000e+08  2.033899e+07  219382.000000
#
#        not_successful     successful   usd_pledged            USD  \
# count   366786.000000  366786.000000  3.667860e+05  366786.000000
# mean         0.635161       0.364839  8.703158e+03       0.787334
# std          0.481386       0.481386  9.053174e+04       0.409194
# min          0.000000       0.000000  0.000000e+00       0.000000
# ...

# %%
pd.value_counts(df['main_category'])
# Out:
# Film & Video      61156
# Music             48739
# Publishing        38586
# Games             34370
# Technology        31630
# Design            29457
# Art               27607
# Food              24082
# Fashion           22285
# Theater           10704
# Comics            10650
# Photography       10571
# Crafts             8601
# Journalism         4637
# Dance              3710
# Graphic Novels        1
# Name: main_category, dtype: int64

# %%
pd.value_counts(df['category'])
# Out:
# Product Design       21863
# Documentary          15899
# Tabletop Games       13909
# Music                13121
# Shorts               11966
# Video Games          11504
# Food                 11300
# Film & Video          8992
# Fiction               8977
# Fashion               8444
# Nonfiction            8195
# Art                   8079
# Theater               6972
# Apparel               6969
# Technology            6752
# Rock                  6666
# Children's Books      6664
# Apps                  6077
# Webseries             5686
# Photography           5662
# Indie Rock            5618
# Publishing            5381
# Narrative Film        5120
# Web                   4977
# Comics                4957
# Crafts                4566
# Country & Folk        4415
# Design                4115
# Hip-Hop               3823
# Hardware              3616
#                      ...
# Couture                261
# Animals                248
# Fabrication Tools      242
# ...

# %% [markdown]
# ## MUSIC (Main_Category)

# %%
dfmusic = df
dfmusic = dfmusic.drop(dfmusic[dfmusic['main_category']!='Music'].index)
dfmusic.head()
# Out:
#         ID                                               name main_category  \
# 1    18520                                 Grandma's are Life         Music
# 11   52687                            Revenge of the Platypus         Music
# 18  106144    Robert Cooper Music's New Album "Wayward Pines"         Music
# 30  197154  North Eugene High School Ukulele Orchestra's F...         Music
# 74  436325                            Music - Comedy - Album!         Music
#
#             category country       state     goal  pledged currency  \
# 1        World Music      US      failed  15000.0    62.00      USD
# 11  Electronic Music      US  successful   1200.0  1201.00      USD
# 18             Music      US      failed   1800.0    15.00      USD
# 30        Indie Rock      US  successful   1450.0  1593.99      USD
# 74             Music      US  successful   1000.0  1125.00      USD
#
#                launched             deadline  backers     state_recat  \
# ...

# %%
pd.value_counts(dfmusic['category'])
# Out:
# Music               13121
# Rock                 6666
# Indie Rock           5618
# Country & Folk       4415
# Hip-Hop              3823
# Pop                  3285
# Classical Music      2574
# Electronic Music     2115
# World Music          2062
# Jazz                 1827
# Faith                1065
# Metal                 701
# R&B                   447
# Punk                  310
# Kids                  275
# Blues                 261
# Latin                 121
# Chiptune               35
# Comedy                 18
# Name: category, dtype: int64

# %%
dfmusic.describe()
# Out:
#                  ID          goal       pledged       backers  not_successful  \
# count  4.873900e+04  4.873900e+04  4.873900e+04  48739.000000    48739.000000
# mean   1.072774e+09  1.612264e+04  4.059568e+03     55.229775        0.506596
# std    6.190072e+08  3.618146e+05  1.459112e+04    203.839604        0.499962
# min    1.852000e+04  1.000000e+00  0.000000e+00      0.000000        0.000000
# 25%    5.349644e+08  1.500000e+03  5.000000e+01      2.000000        0.000000
# 50%    1.067964e+09  4.000000e+03  1.016000e+03     19.000000        1.000000
# 75%    1.609590e+09  1.000000e+04  4.204500e+03     62.000000        1.000000
# max    2.147472e+09  5.000000e+07  1.363037e+06  24883.000000        1.000000
#
#          successful   usd_pledged           USD       not_USD          ratio  \
# count  48739.000000  4.873900e+04  48739.000000  48739.000000   48739.000000
# mean       0.493404  3.854083e+03      0.878516      0.121484       8.307077
# ...

# %%
print(dfmusic[dfmusic['category']=='Music']['successful'].mean())
# Out:
# 0.4817468180778904

# %%
print(dfmusic[dfmusic['category']=='Rock']['successful'].mean())
# Out:
# 0.5243024302430243

# %%
print(dfmusic[dfmusic['category']=='Indie Rock']['successful'].mean())
# Out:
# 0.6422214311142755

# %%
print(dfmusic[dfmusic['category']=='Country & Folk']['successful'].mean())
# Out:
# 0.6355605889014723

# %%
print(dfmusic[dfmusic['category']=='Hip-Hop']['successful'].mean())
# Out:
# 0.15772953178132357

# %%
print(dfmusic[dfmusic['category']=='Pop']['successful'].mean())
# Out:
# 0.4727549467275495

# %%
print(dfmusic[dfmusic['category']=='Classical Music']['successful'].mean())
# Out:
# 0.6390831390831391

# %%
print(dfmusic[dfmusic['category']=='Electronic Music']['successful'].mean())
# Out:
# 0.33144208037825057

# %%
print(dfmusic[dfmusic['category']=='World Music']['successful'].mean())
# Out:
# 0.44713870029097963

# %%
print(dfmusic[dfmusic['category']=='Jazz']['successful'].mean())
# Out:
# 0.6026272577996716

# %%
print(dfmusic[dfmusic['category']=='Faith']['successful'].mean())
# Out:
# 0.4253521126760563

# %%
dfmusic.corr()
# Out:
#                       ID      goal   pledged   backers  not_successful  \
# ID              1.000000  0.002918 -0.002712 -0.001649       -0.002309
# goal            0.002918  1.000000  0.022475  0.005545        0.027843
# pledged        -0.002712  0.022475  1.000000  0.805656       -0.234805
# backers        -0.001649  0.005545  0.805656  1.000000       -0.229354
# not_successful -0.002309  0.027843 -0.234805 -0.229354        1.000000
# successful      0.002309 -0.027843  0.234805  0.229354       -1.000000
# usd_pledged    -0.000710  0.008788  0.907699  0.861810       -0.250385
# USD             0.001896 -0.002945  0.007261  0.025516       -0.070026
# not_USD        -0.001896  0.002945 -0.007261 -0.025516        0.070026
# ratio          -0.003031 -0.000562  0.041641  0.092599       -0.013041
# usd_goal        0.003479  0.995655  0.007439  0.003367        0.028069
#
#                 successful  usd_pledged       USD   not_USD     ratio  \
# ...

# %%
dfmusic[dfmusic['successful']==1].describe()
# Out:
#                  ID           goal       pledged       backers  \
# count  2.404800e+04   24048.000000  2.404800e+04  24048.000000
# mean   1.074222e+09    5915.119330  7.531098e+03    102.601672
# std    6.196494e+08   10067.544865  1.879128e+04    280.979645
# min    5.268700e+04       1.000000  1.000000e+00      1.000000
# 25%    5.373128e+08    1500.000000  1.817245e+03     32.000000
# 50%    1.071597e+09    3017.000000  3.927500e+03     60.000000
# 75%    1.609933e+09    7000.000000  8.285000e+03    108.000000
# max    2.147472e+09  500000.000000  1.363037e+06  24883.000000
#
#        not_successful  successful   usd_pledged           USD       not_USD  \
# count         24048.0     24048.0  2.404800e+04  24048.000000  24048.000000
# mean              0.0         1.0  7.190237e+03      0.901697      0.098303
# std               0.0         0.0  1.793582e+04      0.297731      0.297731
# min               0.0         1.0  0.000000e+00      0.000000      0.000000
# ...

# %%
print(len(dfmusic[(dfmusic['successful']==1) & (dfmusic['usd_goal']>=100000)]))
# Out:
# 31

# %%
print(len(dfmusic[(dfmusic['successful']==1) & (dfmusic['usd_goal']>=150000)]))
# Out:
# 11

# %%
print(len(dfmusic[(dfmusic['successful']==1) & (dfmusic['usd_goal']>=200000)]))
# Out:
# 4

# %%
dfmusic[(dfmusic['successful']==1) & (dfmusic['usd_goal']>=200000)].head()
# Out:
#                 ID                                         name main_category  \
# 147960   864588968             New Carman Album and Music Video         Music
# 254928  1489765898     Smithsonian Anthology of Hip-Hop and Rap         Music
# 270139  1578567890  Foo For The Fans - No More Touts (Canceled)         Music
# 315564  1845154468                              Electronic Opus         Music
#
#                 category country       state      goal    pledged currency  \
# 147960             Faith      US  successful  200000.0  538103.02      USD
# 254928           Hip-Hop      US  successful  250000.0  368841.00      USD
# 270139              Rock      GB    canceled  150000.0  150245.02      GBP
# 315564  Electronic Music      US  successful  200000.0  254767.00      USD
#
#                    launched             deadline  backers state_recat  \
# 147960  2013-04-20 05:11:38           2013-06-19     5043  successful
# ...

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='successful ~ usd_goal + usd_pledged + backers + USD - 1', data=dfmusic).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.493
# Model:                            OLS   Adj. R-squared:                  0.493
# Method:                 Least Squares   F-statistic:                 1.183e+04
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:46   Log-Likelihood:                -35408.
# No. Observations:               48739   AIC:                         7.082e+04
# Df Residuals:                   48735   BIC:                         7.086e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# usd_goal    -3.481e-08   6.26e-09     -5.566      0.000   -4.71e-08   -2.26e-08
# ...

# %%
import statsmodels.formula.api as sm
result = sm.ols(formula='successful ~ usd_pledged + backers + USD + usd_pledged*backers + usd_goal*backers - 1', data=dfmusic).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.533
# Model:                            OLS   Adj. R-squared:                  0.533
# Method:                 Least Squares   F-statistic:                     9263.
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:46   Log-Likelihood:                -33397.
# No. Observations:               48739   AIC:                         6.681e+04
# Df Residuals:                   48733   BIC:                         6.686e+04
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## INDIE ROCK (Category under Music)

# %%
dfmusic[dfmusic['category']=='Indie Rock'].describe()
# Out:
#                  ID          goal        pledged      backers  not_successful  \
# count  5.618000e+03  5.618000e+03    5618.000000  5618.000000     5618.000000
# mean   1.081038e+09  6.084059e+03    3949.269258    61.471164        0.357779
# std    6.122453e+08  3.392036e+04    8922.501955   135.640601        0.479389
# min    1.971540e+05  1.000000e+00       0.000000     0.000000        0.000000
# 25%    5.521445e+08  1.500000e+03     368.250000     9.000000        0.000000
# 50%    1.084699e+09  3.000000e+03    1790.000000    33.000000        0.000000
# 75%    1.609004e+09  6.000000e+03    4637.500000    71.000000        1.000000
# max    2.147422e+09  1.957167e+06  278486.000000  3305.000000        1.000000
#
#         successful    usd_pledged          USD      not_USD        ratio  \
# count  5618.000000    5618.000000  5618.000000  5618.000000  5618.000000
# mean      0.642221    3889.145354     0.939480     0.060520     2.200960
# ...

# %%
dfmusic[dfmusic['category']=='Indie Rock'].corr()
# Out:
#                       ID      goal   pledged   backers  not_successful  \
# ID              1.000000 -0.015417 -0.006633 -0.013822        0.009825
# goal           -0.015417  1.000000  0.137113  0.098114        0.061876
# pledged        -0.006633  0.137113  1.000000  0.873726       -0.270484
# backers        -0.013822  0.098114  0.873726  1.000000       -0.272454
# not_successful  0.009825  0.061876 -0.270484 -0.272454        1.000000
# successful     -0.009825 -0.061876  0.270484  0.272454       -1.000000
# usd_pledged    -0.010746  0.129900  0.972484  0.895284       -0.274912
# USD             0.006450 -0.064485  0.036205  0.050340       -0.064403
# not_USD        -0.006450  0.064485 -0.036205 -0.050340        0.064403
# ratio          -0.004849 -0.005659  0.001295  0.007745       -0.031521
# usd_goal       -0.015818  0.994622  0.112158  0.086781        0.056490
#
#                 successful  usd_pledged       USD   not_USD     ratio  \
# ...

# %%
dfmusic[(dfmusic['category']=='Indie Rock') & (dfmusic['successful']==1)].describe()
# Out:
#                  ID           goal        pledged      backers  \
# count  3.608000e+03    3608.000000    3608.000000  3608.000000
# mean   1.076549e+09    4517.632614    5750.439745    89.052106
# std    6.172556e+08    6892.735938   10597.206101   161.206138
# min    1.971540e+05       1.000000      12.000000     1.000000
# 25%    5.344180e+08    1200.000000    1620.000000    31.000000
# 50%    1.069153e+09    2815.500000    3230.995000    55.000000
# 75%    1.618473e+09    5000.000000    6330.245000    96.000000
# max    2.147422e+09  150000.000000  278486.000000  3305.000000
#
#        not_successful  successful    usd_pledged          USD      not_USD  \
# count          3608.0      3608.0    3608.000000  3608.000000  3608.000000
# mean              0.0         1.0    5675.644354     0.950942     0.049058
# std               0.0         0.0   10334.137763     0.216018     0.216018
# min               0.0         1.0       0.000000     0.000000     0.000000
# ...

# %%
result = sm.ols(formula='successful ~ usd_goal + usd_pledged + backers + USD - 1', data=dfmusic[dfmusic['category']=='Indie Rock']).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.650
# Model:                            OLS   Adj. R-squared:                  0.650
# Method:                 Least Squares   F-statistic:                     2608.
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:47   Log-Likelihood:                -3777.9
# No. Observations:                5618   AIC:                             7564.
# Df Residuals:                    5614   BIC:                             7590.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# usd_goal    -7.679e-07   1.67e-07     -4.604      0.000   -1.09e-06   -4.41e-07
# ...

# %%
result = sm.ols(formula='successful ~ usd_goal + usd_pledged + backers + USD + usd_pledged*backers - 1', data=dfmusic[dfmusic['category']=='Indie Rock']).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.683
# Model:                            OLS   Adj. R-squared:                  0.683
# Method:                 Least Squares   F-statistic:                     2421.
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:47   Log-Likelihood:                -3499.0
# No. Observations:                5618   AIC:                             7008.
# Df Residuals:                    5613   BIC:                             7041.
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## CLASSICAL MUSIC (Category under Music)

# %%
dfmusic[dfmusic['category']=='Classical Music'].describe()
# Out:
#                  ID          goal       pledged      backers  not_successful  \
# count  2.574000e+03  2.574000e+03  2.574000e+03  2574.000000     2574.000000
# mean   1.048709e+09  1.020019e+04  5.190531e+03    54.281274        0.360917
# std    6.250274e+08  6.830946e+04  2.349523e+04   141.140948        0.480360
# min    6.597960e+05  1.000000e+00  0.000000e+00     0.000000        0.000000
# 25%    4.840916e+08  2.000000e+03  5.200000e+02     9.000000        0.000000
# 50%    1.063319e+09  4.000000e+03  2.190500e+03    30.000000        0.000000
# 75%    1.578336e+09  8.000000e+03  5.525000e+03    66.000000        1.000000
# max    2.147431e+09  3.000000e+06  1.058547e+06  4256.000000        1.000000
#
#         successful    usd_pledged          USD      not_USD        ratio  \
# count  2574.000000    2574.000000  2574.000000  2574.000000  2574.000000
# mean      0.639083    4432.395893     0.836830     0.163170     1.079545
# ...

# %%
dfmusic[dfmusic['category']=='Classical Music'].corr()
# Out:
#                       ID      goal   pledged   backers  not_successful  \
# ID              1.000000 -0.011214 -0.005538  0.007670       -0.021021
# goal           -0.011214  1.000000  0.884326  0.295337        0.084434
# pledged        -0.005538  0.884326  1.000000  0.539258       -0.093067
# backers         0.007670  0.295337  0.539258  1.000000       -0.215662
# not_successful -0.021021  0.084434 -0.093067 -0.215662        1.000000
# successful      0.021021 -0.084434  0.093067  0.215662       -1.000000
# usd_pledged     0.008334  0.402432  0.669044  0.750996       -0.305653
# USD             0.008489 -0.073764 -0.054704  0.007630       -0.075339
# not_USD        -0.008489  0.073764  0.054704 -0.007630        0.075339
# ratio           0.047788 -0.013022  0.008324  0.047918       -0.110063
# usd_goal       -0.027511  0.222744  0.170923  0.073716        0.092699
#
#                 successful  usd_pledged       USD   not_USD     ratio  \
# ...

# %%
dfmusic[(dfmusic['category']=='Classical Music') & (dfmusic['successful']==1)].describe()
# Out:
#                  ID           goal        pledged      backers  \
# count  1.645000e+03    1645.000000    1645.000000  1645.000000
# mean   1.058580e+09    5866.713070    6833.455994    77.151368
# std    6.277447e+08   10191.461462   12044.514769   163.027320
# min    9.826290e+05       1.000000       6.000000     1.000000
# 25%    4.911039e+08    1635.000000    2055.000000    28.000000
# 50%    1.077733e+09    3500.000000    4058.000000    52.000000
# 75%    1.584070e+09    7000.000000    7825.000000    87.000000
# max    2.147431e+09  250000.000000  264967.000000  4256.000000
#
#        not_successful  successful    usd_pledged          USD      not_USD  \
# count          1645.0      1645.0    1645.000000  1645.000000  1645.000000
# mean              0.0         1.0    6325.910284     0.857751     0.142249
# std               0.0         0.0    8711.746032     0.349412     0.349412
# min               0.0         1.0       0.000000     0.000000     0.000000
# ...

# %%
result = sm.ols(formula='successful ~ usd_goal + usd_pledged + USD + ratio - 1', data=dfmusic[dfmusic['category']=='Classical Music']).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.620
# Model:                            OLS   Adj. R-squared:                  0.620
# Method:                 Least Squares   F-statistic:                     1050.
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:48   Log-Likelihood:                -1829.3
# No. Observations:                2574   AIC:                             3667.
# Df Residuals:                    2570   BIC:                             3690.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# usd_goal    -7.499e-07   1.75e-07     -4.278      0.000   -1.09e-06   -4.06e-07
# ...

# %%
result = sm.ols(formula='successful ~ usd_goal + usd_pledged + backers + USD + ratio + usd_pledged*backers - 1', data=dfmusic[dfmusic['category']=='Classical Music']).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.674
# Model:                            OLS   Adj. R-squared:                  0.674
# Method:                 Least Squares   F-statistic:                     886.3
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:48   Log-Likelihood:                -1632.2
# No. Observations:                2574   AIC:                             3276.
# Df Residuals:                    2568   BIC:                             3312.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## VIDEO GAMES (Category under Games)

# %%
dfvideogames = df
dfvideogames = dfvideogames.drop(dfvideogames[dfvideogames['category']!='Video Games'].index)
dfvideogames.head()
# Out:
#           ID                                               name main_category  \
# 28    188667                                          Last-Wars         Games
# 185  1058397  Mystery World Dizzy - A 'new' old game by The ...         Games
# 190  1086007                                      Melee Masters         Games
# 244  1394048                      Out of Sync Cup - ZeroEmpires         Games
# 249  1403417     Liora - RPG meets Tower Defense/Castle Defense         Games
#
#         category country       state      goal   pledged currency  \
# 28   Video Games      CA      failed   35000.0    621.00      CAD
# 185  Video Games      GB  successful   12500.0  28016.00      GBP
# 190  Video Games      US    canceled  125000.0    360.00      USD
# 244  Video Games      GB  successful     120.0    316.12      GBP
# 249  Video Games      CA      failed   25000.0   6722.00      CAD
#
#                 launched             deadline  backers     state_recat  \
# ...

# %%
dfvideogames.describe()
# Out:
#                  ID          goal       pledged       backers  not_successful  \
# count  1.150400e+04  1.150400e+04  1.150400e+04  11504.000000    11504.000000
# mean   1.070730e+09  7.811050e+04  1.839227e+04    378.282684        0.791551
# std    6.188462e+08  1.134065e+06  1.469071e+05   2513.751598        0.406217
# min    1.886670e+05  1.000000e+00  0.000000e+00      0.000000        0.000000
# 25%    5.328705e+08  3.287500e+03  4.100000e+01      3.000000        1.000000
# 50%    1.066891e+09  1.000000e+04  4.300000e+02     13.000000        1.000000
# 75%    1.605056e+09  4.000000e+04  4.309438e+03     90.000000        1.000000
# max    2.147161e+09  1.000000e+08  6.333296e+06  87142.000000        1.000000
#
#          successful   usd_pledged           USD       not_USD         ratio  \
# count  11504.000000  1.150400e+04  11504.000000  11504.000000  11504.000000
# mean       0.208449  1.772766e+04      0.663334      0.336666      6.818652
# ...

# %%
dfvideogames.corr()
# Out:
#                       ID      goal   pledged   backers  not_successful  \
# ID              1.000000 -0.005117 -0.004238 -0.003803       -0.003864
# goal           -0.005117  1.000000  0.038504  0.031735        0.018624
# pledged        -0.004238  0.038504  1.000000  0.916124       -0.195150
# backers        -0.003803  0.031735  0.916124  1.000000       -0.239291
# not_successful -0.003864  0.018624 -0.195150 -0.239291        1.000000
# successful      0.003864 -0.018624  0.195150  0.239291       -1.000000
# usd_pledged    -0.006469  0.036668  0.989827  0.924407       -0.186858
# USD             0.013389  0.011149  0.039779  0.036717       -0.039997
# not_USD        -0.013389 -0.011149 -0.039779 -0.036717        0.039997
# ratio           0.011866 -0.001070  0.001786  0.004508       -0.030948
# usd_goal       -0.005079  0.993650  0.037628  0.032996        0.018492
#
#                 successful  usd_pledged       USD   not_USD     ratio  \
# ...

# %%
dfvideogames[dfvideogames['successful']==1].describe()
# Out:
#                  ID          goal       pledged       backers  not_successful  \
# count  2.398000e+03  2.398000e+03  2.398000e+03   2398.000000          2398.0
# mean   1.075389e+09  3.695479e+04  7.425615e+04   1550.396997             0.0
# std    6.145491e+08  1.183519e+05  3.135701e+05   5310.569968             0.0
# min    1.058397e+06  1.000000e+00  3.000000e+00      1.000000             0.0
# 25%    5.380320e+08  1.500000e+03  2.783767e+03     68.000000             0.0
# 50%    1.088288e+09  7.500000e+03  1.118326e+04    282.500000             0.0
# 75%    1.595449e+09  2.500000e+04  4.173957e+04   1123.500000             0.0
# max    2.147161e+09  2.000000e+06  6.333296e+06  87142.000000             0.0
#
#        successful   usd_pledged          USD      not_USD         ratio  \
# count      2398.0  2.398000e+03  2398.000000  2398.000000   2398.000000
# mean          1.0  7.235249e+04     0.700167     0.299833     32.368628
# ...

# %%
result = sm.ols(formula='successful ~ usd_pledged + backers + ratio  + USD - 1', data=dfvideogames).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.214
# Model:                            OLS   Adj. R-squared:                  0.214
# Method:                 Least Squares   F-statistic:                     783.2
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:50   Log-Likelihood:                -5918.2
# No. Observations:               11504   AIC:                         1.184e+04
# Df Residuals:                   11500   BIC:                         1.187e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# usd_pledged  -7.42e-07   6.59e-08    -11.260      0.000   -8.71e-07   -6.13e-07
# ...

# %%
result = sm.ols(formula='successful ~ usd_pledged + backers + ratio  + USD + usd_pledged*backers - 1', data=dfvideogames).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.257
# Model:                            OLS   Adj. R-squared:                  0.257
# Method:                 Least Squares   F-statistic:                     796.4
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:50   Log-Likelihood:                -5593.7
# No. Observations:               11504   AIC:                         1.120e+04
# Df Residuals:                   11499   BIC:                         1.123e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %%
dfvideogames2 = dfvideogames
dfvideogames2 = dfvideogames2.drop(dfvideogames2[dfvideogames2['usd_goal']>2500000].index)
dfvideogames2.head()
# Out:
#           ID                                               name main_category  \
# 28    188667                                          Last-Wars         Games
# 185  1058397  Mystery World Dizzy - A 'new' old game by The ...         Games
# 190  1086007                                      Melee Masters         Games
# 244  1394048                      Out of Sync Cup - ZeroEmpires         Games
# 249  1403417     Liora - RPG meets Tower Defense/Castle Defense         Games
#
#         category country       state      goal   pledged currency  \
# 28   Video Games      CA      failed   35000.0    621.00      CAD
# 185  Video Games      GB  successful   12500.0  28016.00      GBP
# 190  Video Games      US    canceled  125000.0    360.00      USD
# 244  Video Games      GB  successful     120.0    316.12      GBP
# 249  Video Games      CA      failed   25000.0   6722.00      CAD
#
#                 launched             deadline  backers     state_recat  \
# ...

# %%
dfvideogames2.describe()
# Out:
#                  ID          goal       pledged       backers  not_successful  \
# count  1.147900e+04  1.147900e+04  1.147900e+04  11479.000000    11479.000000
# mean   1.070665e+09  5.238376e+04  1.843213e+04    379.099138        0.791097
# std    6.186688e+08  1.581232e+05  1.470645e+05   2516.426721        0.406543
# min    1.886670e+05  1.000000e+00  0.000000e+00      0.000000        0.000000
# 25%    5.332566e+08  3.200000e+03  4.100000e+01      3.000000        1.000000
# 50%    1.066891e+09  1.000000e+04  4.340000e+02     13.000000        1.000000
# 75%    1.604638e+09  4.000000e+04  4.334500e+03     90.000000        1.000000
# max    2.147161e+09  5.000000e+06  6.333296e+06  87142.000000        1.000000
#
#          successful   usd_pledged           USD       not_USD         ratio  \
# count  11479.000000  1.147900e+04  11479.000000  11479.000000  11479.000000
# mean       0.208903  1.776607e+04      0.663560      0.336440      6.833502
# ...

# %%
dfvideogames2.corr()
# Out:
#                       ID      goal   pledged   backers  not_successful  \
# ID              1.000000 -0.003770 -0.004230 -0.003791       -0.003924
# goal           -0.003770  1.000000  0.296750  0.251892        0.050144
# pledged        -0.004230  0.296750  1.000000  0.916121       -0.195070
# backers        -0.003791  0.251892  0.916121  1.000000       -0.239199
# not_successful -0.003924  0.050144 -0.195070 -0.239199        1.000000
# successful      0.003924 -0.050144  0.195070  0.239199       -1.000000
# usd_pledged    -0.006464  0.282428  0.989827  0.924406       -0.186783
# USD             0.013796  0.038033  0.039769  0.036692       -0.039814
# not_USD        -0.013796 -0.038033 -0.039769 -0.036692        0.039814
# ratio           0.011884 -0.005063  0.001782  0.004503       -0.030939
# usd_goal       -0.009131  0.871355  0.314771  0.283082        0.049186
#
#                 successful  usd_pledged       USD   not_USD     ratio  \
# ...

# %%
dfvideogames2[dfvideogames2['successful']==1].describe()
# Out:
#                  ID          goal       pledged       backers  not_successful  \
# count  2.398000e+03  2.398000e+03  2.398000e+03   2398.000000          2398.0
# mean   1.075389e+09  3.695479e+04  7.425615e+04   1550.396997             0.0
# std    6.145491e+08  1.183519e+05  3.135701e+05   5310.569968             0.0
# min    1.058397e+06  1.000000e+00  3.000000e+00      1.000000             0.0
# 25%    5.380320e+08  1.500000e+03  2.783767e+03     68.000000             0.0
# 50%    1.088288e+09  7.500000e+03  1.118326e+04    282.500000             0.0
# 75%    1.595449e+09  2.500000e+04  4.173957e+04   1123.500000             0.0
# max    2.147161e+09  2.000000e+06  6.333296e+06  87142.000000             0.0
#
#        successful   usd_pledged          USD      not_USD         ratio  \
# count      2398.0  2.398000e+03  2398.000000  2398.000000   2398.000000
# mean          1.0  7.235249e+04     0.700167     0.299833     32.368628
# ...

# %%
result = sm.ols(formula='successful ~ usd_goal + usd_pledged + backers + ratio  + USD - 1', data=dfvideogames2).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.219
# Model:                            OLS   Adj. R-squared:                  0.218
# Method:                 Least Squares   F-statistic:                     642.6
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:51   Log-Likelihood:                -5883.7
# No. Observations:               11479   AIC:                         1.178e+04
# Df Residuals:                   11474   BIC:                         1.181e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# usd_goal    -2.194e-07   2.72e-08     -8.062      0.000   -2.73e-07   -1.66e-07
# ...

# %%
result = sm.ols(formula='successful ~ usd_goal + usd_pledged + backers + ratio  + USD + usd_pledged*backers + ratio*backers - 1', data=dfvideogames2).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.268
# Model:                            OLS   Adj. R-squared:                  0.268
# Method:                 Least Squares   F-statistic:                     601.4
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:52   Log-Likelihood:                -5506.5
# No. Observations:               11479   AIC:                         1.103e+04
# Df Residuals:                   11472   BIC:                         1.108e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ## Tabletop Games (Category under Games)

# %%
dftablegames = df
dftablegames = dftablegames.drop(dftablegames[dftablegames['category']!='Tabletop Games'].index)
dftablegames.head()
# Out:
#          ID                                               name main_category  \
# 14    62304                                      sinbin trivia         Games
# 21   126581               Educational Online Trading Card Game         Games
# 69   401060                    NODE - Ask meaningful questions         Games
# 151  885958                            Wilderness Empires Game         Games
# 172  998541  SideQuests: Easy Adventure Modules for 5E Dung...         Games
#
#            category country       state     goal  pledged currency  \
# 14   Tabletop Games      GB      failed  65000.0     11.0      GBP
# 21   Tabletop Games      US      failed   4000.0     20.0      USD
# 69   Tabletop Games      DE  successful   3000.0   3442.0      EUR
# 151  Tabletop Games      US  successful   5000.0  17302.0      USD
# 172  Tabletop Games      CA  successful   1500.0   7711.0      CAD
#
#                 launched             deadline  backers     state_recat  \
# ...

# %%
dftablegames.describe()
# Out:
#                  ID          goal       pledged        backers  \
# count  1.390900e+04  1.390900e+04  1.390900e+04   13909.000000
# mean   1.064426e+09  1.543192e+04  3.441107e+04     430.175857
# std    6.218515e+08  4.460237e+04  2.177097e+05    2451.559581
# min    6.230400e+04  1.000000e+00  0.000000e+00       0.000000
# 25%    5.252338e+08  2.500000e+03  1.006000e+03      24.000000
# 50%    1.059060e+09  7.000000e+03  4.573000e+03      97.000000
# 75%    1.604255e+09  1.550000e+04  1.641100e+04     304.000000
# max    2.147389e+09  1.949000e+06  1.239314e+07  219382.000000
#
#        not_successful    successful   usd_pledged           USD       not_USD  \
# count    13909.000000  13909.000000  1.390900e+04  13909.000000  13909.000000
# mean         0.431735      0.568265  3.105146e+04      0.756273      0.243727
# std          0.495336      0.495336  2.113894e+05      0.429345      0.429345
# min          0.000000      0.000000  0.000000e+00      0.000000      0.000000
# ...

# %%
dftablegames.corr()
# Out:
#                       ID      goal   pledged   backers  not_successful  \
# ID              1.000000 -0.017423  0.000210  0.011640       -0.016067
# goal           -0.017423  1.000000  0.132361  0.053798        0.131286
# pledged         0.000210  0.132361  1.000000  0.684635       -0.125200
# backers         0.011640  0.053798  0.684635  1.000000       -0.134666
# not_successful -0.016067  0.131286 -0.125200 -0.134666        1.000000
# successful      0.016067 -0.131286  0.125200  0.134666       -1.000000
# usd_pledged     0.000460  0.107616  0.958835  0.697218       -0.116352
# USD             0.001584 -0.005564  0.017161  0.036135       -0.007580
# not_USD        -0.001584  0.005564 -0.017161 -0.036135        0.007580
# ratio           0.014297 -0.008804  0.016132  0.026544       -0.027066
# usd_goal       -0.009154  0.237590  0.028784  0.012994        0.053589
#
#                 successful  usd_pledged       USD   not_USD     ratio  \
# ...

# %%
dftablegames[dftablegames['successful']==1].describe()
# Out:
#                  ID           goal       pledged        backers  \
# count  7.904000e+03    7904.000000  7.904000e+03    7904.000000
# mean   1.073134e+09   10328.141574  5.816847e+04     717.926746
# std    6.209941e+08   19533.138083  2.864674e+05    3221.822674
# min    4.010600e+05       1.000000  2.000000e+00       1.000000
# 25%    5.341970e+08    1500.000000  4.477750e+03     102.000000
# 50%    1.075728e+09    5000.000000  1.174850e+04     238.000000
# 75%    1.618766e+09   11000.000000  3.401150e+04     618.000000
# max    2.147389e+09  500000.000000  1.239314e+07  219382.000000
#
#        not_successful  successful   usd_pledged          USD      not_USD  \
# count          7904.0      7904.0  7.904000e+03  7904.000000  7904.000000
# mean              0.0         1.0  5.248900e+04     0.759109     0.240891
# std               0.0         0.0  2.784665e+05     0.427651     0.427651
# min               0.0         1.0  0.000000e+00     0.000000     0.000000
# ...

# %%
result = sm.ols(formula='successful ~ backers + USD - 1', data=dftablegames).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.445
# Model:                            OLS   Adj. R-squared:                  0.445
# Method:                 Least Squares   F-statistic:                     5570.
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:53   Log-Likelihood:                -11714.
# No. Observations:               13909   AIC:                         2.343e+04
# Df Residuals:                   13907   BIC:                         2.345e+04
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# backers     3.334e-05   1.94e-06     17.174      0.000    2.95e-05    3.71e-05
# ...

# %%
result = sm.ols(formula='successful ~ backers + USD + backers*USD - 1', data=dftablegames).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.471
# Model:                            OLS   Adj. R-squared:                  0.471
# Method:                 Least Squares   F-statistic:                     4123.
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:54   Log-Likelihood:                -11381.
# No. Observations:               13909   AIC:                         2.277e+04
# Df Residuals:                   13906   BIC:                         2.279e+04
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# backers         0.0003   1.01e-05     28.947      0.000       0.000       0.000
# ...

# %% [markdown]
# ## PRODUCT DESIGN (Category under Design)

# %%
dfproductdesign = df
dfproductdesign = dfproductdesign.drop(dfproductdesign[dfproductdesign['category']!='Product Design'].index)
dfproductdesign.head()
# Out:
#          ID                              name main_category        category  \
# 41   277920                   EveryGirl InBin        Design  Product Design
# 54   326455                Clutch Lead Holder        Design  Product Design
# 77   452247  SooperCrapz - DIY vinyl art toys        Design  Product Design
# 87   518181      SPREADEM Bedding: Pool Print        Design  Product Design
# 103  618765                    Awning Project        Design  Product Design
#
#     country       state      goal  pledged currency             launched  \
# 41       AU      failed  150000.0    590.0      AUD  2015-09-28 22:26:53
# 54       US  successful    5500.0  19300.0      USD  2012-06-23 00:01:44
# 77       GB      failed   33200.0    567.0      GBP  2017-10-03 22:06:44
# 87       AU      failed   12000.0   7334.0      AUD  2015-07-17 00:00:46
# 103      US      failed    3500.0   1066.0      USD  2014-09-10 23:59:13
#
# ...

# %%
dfproductdesign.describe()
# Out:
#                  ID          goal       pledged        backers  \
# count  2.186300e+04  2.186300e+04  2.186300e+04   21863.000000
# mean   1.075032e+09  3.502806e+04  3.188751e+04     278.993505
# std    6.201067e+08  3.600073e+05  2.599236e+05    1755.576925
# min    2.779200e+05  1.000000e+00  0.000000e+00       0.000000
# 25%    5.370840e+08  5.000000e+03  4.010000e+02       8.000000
# 50%    1.072421e+09  1.250000e+04  2.701000e+03      37.000000
# 75%    1.613709e+09  3.000000e+04  1.422950e+04     146.000000
# max    2.147350e+09  5.000000e+07  2.033899e+07  154926.000000
#
#        not_successful    successful   usd_pledged           USD       not_USD  \
# count    21863.000000  21863.000000  2.186300e+04  21863.000000  21863.000000
# mean         0.629008      0.370992  2.649326e+04      0.733431      0.266569
# std          0.483081      0.483081  2.422700e+05      0.442175      0.442175
# min          0.000000      0.000000  0.000000e+00      0.000000      0.000000
# ...

# %%
dfproductdesign.corr()
# Out:
#                       ID      goal   pledged   backers  not_successful  \
# ID              1.000000 -0.010577  0.004456  0.004380       -0.004740
# goal           -0.010577  1.000000  0.031011  0.008704        0.032500
# pledged         0.004456  0.031011  1.000000  0.741828       -0.140460
# backers         0.004380  0.008704  0.741828  1.000000       -0.179666
# not_successful -0.004740  0.032500 -0.140460 -0.179666        1.000000
# successful      0.004740 -0.032500  0.140460  0.179666       -1.000000
# usd_pledged     0.003353  0.019360  0.935122  0.763962       -0.125245
# USD             0.017883 -0.011847 -0.001067  0.028839       -0.001743
# not_USD        -0.017883  0.011847  0.001067 -0.028839        0.001743
# ratio          -0.006650 -0.007018  0.257993  0.351745       -0.161622
# usd_goal       -0.001828  0.835375  0.014246  0.006390        0.032458
#
#                 successful  usd_pledged       USD   not_USD     ratio  \
# ...

# %%
dfproductdesign[dfproductdesign['successful']==1].describe()
# Out:
#                  ID          goal       pledged        backers  \
# count  8.111000e+03  8.111000e+03  8.111000e+03    8111.000000
# mean   1.078859e+09  1.979337e+04  7.942489e+04     689.691530
# std    6.212365e+08  4.401326e+04  4.222222e+05    2833.896157
# min    3.264550e+05  1.000000e+00  5.000000e+00       1.000000
# 25%    5.295840e+08  3.300000e+03  6.467500e+03      81.000000
# 50%    1.088101e+09  1.000000e+04  1.895900e+04     199.000000
# 75%    1.617973e+09  2.000000e+04  5.111350e+04     542.000000
# max    2.147022e+09  1.400000e+06  2.033899e+07  154926.000000
#
#        not_successful  successful   usd_pledged          USD      not_USD  \
# count          8111.0      8111.0  8.111000e+03  8111.000000  8111.000000
# mean              0.0         1.0  6.600219e+04     0.734435     0.265565
# std               0.0         0.0  3.944263e+05     0.441661     0.441661
# min               0.0         1.0  0.000000e+00     0.000000     0.000000
# ...

# %%
result = sm.ols(formula='successful ~ usd_pledged + backers + ratio  + USD - 1', data=dfproductdesign).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.309
# Model:                            OLS   Adj. R-squared:                  0.308
# Method:                 Least Squares   F-statistic:                     2439.
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:55   Log-Likelihood:                -16149.
# No. Observations:               21863   AIC:                         3.231e+04
# Df Residuals:                   21859   BIC:                         3.234e+04
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# usd_pledged -8.212e-08   2.19e-08     -3.747      0.000   -1.25e-07   -3.92e-08
# ...

# %%
result = sm.ols(formula='successful ~ usd_pledged + backers + ratio  + USD + usd_pledged*backers - 1', data=dfproductdesign).fit()
result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:             successful   R-squared:                       0.345
# Model:                            OLS   Adj. R-squared:                  0.345
# Method:                 Least Squares   F-statistic:                     2302.
# Date:                Sat, 14 Jul 2018   Prob (F-statistic):               0.00
# Time:                        11:51:55   Log-Likelihood:                -15559.
# No. Observations:               21863   AIC:                         3.113e+04
# Df Residuals:                   21858   BIC:                         3.117e+04
# Df Model:                           5
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# ...
